# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %%
plt.figure(figsize=(10,6))
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.25945199,  6.09476785],
#        [-9.46941837, -6.56081545],
#        [-4.71967657,  7.92178508],
#        [ 4.3172263 ,  7.04477898],
#        [ 0.14363806,  1.2030127 ]])

# %%
kmeans.labels_
# Out:
# array([2, 3, 4, 3, 3, 1, 3, 4, 0, 4, 2, 4, 3, 3, 2, 4, 3, 4, 1, 2, 1, 4,
#        4, 1, 2, 1, 1, 4, 3, 3, 2, 1, 3, 4, 4, 2, 1, 1, 1, 4, 1, 2, 0, 2,
#        4, 0, 2, 4, 1, 0, 4, 2, 3, 4, 1, 0, 0, 4, 2, 3, 1, 0, 1, 0, 3, 4,
#        1, 3, 3, 1, 3, 0, 1, 0, 1, 3, 3, 4, 2, 4, 0, 1, 3, 1, 4, 4, 4, 2,
#        0, 1, 1, 1, 1, 0, 0, 1, 3, 2, 1, 3, 0, 1, 4, 4, 0, 0, 1, 3, 1, 1,
#        3, 2, 2, 3, 1, 3, 2, 2, 0, 0, 0, 2, 4, 2, 4, 3, 2, 4, 1, 0, 2, 2,
#        4, 1, 1, 2, 3, 2, 3, 4, 1, 3, 1, 0, 0, 3, 0, 1, 2, 2, 2, 2, 4, 3,
#        4, 2, 0, 3, 3, 4, 3, 4, 0, 2, 1, 2, 4, 3, 2, 4, 3, 4, 2, 0, 0, 2,
#        3, 0, 1, 0, 2, 1, 1, 0, 1, 1, 1, 1, 1, 4, 1, 3, 3, 2, 1, 0, 3, 3,
#        1, 4], dtype=int32)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(10,6))

ax1.set_title('KMeans Predictions')
ax1.scatter(data[0][:,0], data[0][:, 1], c=kmeans.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:, 1], c=data[1], cmap='rainbow')
